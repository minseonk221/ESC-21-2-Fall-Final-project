# %% [markdown]
# - X53 equity / fixed assets
# - X54 constant capital / fixed assets
# - X55 working capital
# - X56 (sales - cost of products sold) / sales
# - X57 (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)
# - X58 total costs /total sales
# - X59 long-term liabilities / equity
# - X60 sales / inventory
# - X61 sales / receivables
# - X62 (short-term liabilities *365) / sales
# - X63 sales / short-term liabilities
# - X64 sales / fixed assets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
original_df = pd.read_csv('FS_2y_before_Bankruptcy_train.csv', na_values = '?')

# %%
df = original_df[['Attr53', 'Attr54', 'Attr55', 'Attr56', 'Attr57',
       'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63', 'Attr64',
       'class']].sort_values('class')

# %%
df.corr()
# Out:
#           Attr53    Attr54    Attr55    Attr56    Attr57    Attr58    Attr59  \
# Attr53  1.000000  0.819631 -0.002401  0.000429  0.002042  0.002712 -0.000826
# Attr54  0.819631  1.000000 -0.001997  0.000382  0.001938  0.000626  0.000069
# Attr55 -0.002401 -0.001997  1.000000  0.001770 -0.003229 -0.003300 -0.001997
# Attr56  0.000429  0.000382  0.001770  1.000000  0.000088 -0.095592  0.000427
# Attr57  0.002042  0.001938 -0.003229  0.000088  1.000000 -0.001567 -0.500015
# Attr58  0.002712  0.000626 -0.003300 -0.095592 -0.001567  1.000000 -0.000899
# Attr59 -0.000826  0.000069 -0.001997  0.000427 -0.500015 -0.000899  1.000000
# Attr60  0.000599  0.000038 -0.001343  0.000440 -0.000100 -0.000409 -0.000605
# Attr61 -0.000468 -0.000483 -0.001631  0.000506  0.000151 -0.001784 -0.000584
# Attr62 -0.002369 -0.001339 -0.001993 -0.113332 -0.000095  0.126958 -0.000498
# Attr63  0.006219  0.002743 -0.000444  0.001888  0.001079 -0.003048 -0.001754
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %%
plt.scatter(df.Attr53, df.Attr54)
plt.show()

# %%
plt.scatter(df.Attr53, df.Attr64)
plt.show()

# %%
df.shape
# Out:
# (6855, 13)

# %%
df.isna().sum()
# Out:
# Attr53    162
# Attr54    162
# Attr55      0
# Attr56     14
# Attr57      1
# Attr58     10
# Attr59      1
# Attr60    420
# Attr61     20
# Attr62     14
# Attr63     28
# Attr64    162
# class       0
# dtype: int64

# %%
plt.scatter(range(6855), df['class'])
plt.show()

# %%
 df.Attr53[df.Attr53!=0].shape
# Out:
# (6854,)

# %%
temp =  df.Attr53
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr54
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr55
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr56
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr57
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr58
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr59
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr60
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr61
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr62
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr63
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()

# %%
temp =  df.Attr64
plt.scatter(range(6855), temp)
plt.show()
temp_2 = temp[(temp.values > max(temp)/10) + (temp.values < -max(temp)/10)]
plt.scatter(range(temp_2.shape[0]),temp_2)
plt.show()
