# %%
import pandas as pd
import pandas_profiling
import numpy as np
import seaborn as sns
from pandas_profiling import ProfileReport
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('FS_2y_before_Bankruptcy_train_preprocessed.csv',encoding='utf-8')

# %%
df_liq = df[['Attr4','Attr40']]
df_op_prof = df[['Attr42','Attr49']]
df_bsns_rsk = df[['Attr13','Attr19']]
df_fncl_rsk = df[['Attr10','Attr2','Attr25']]

# %%
from sklearn.preprocessing import StandardScaler
df_liq = StandardScaler().fit_transform(df_liq)
df_op_prof = StandardScaler().fit_transform(df_op_prof)
df_bsns_rsk = StandardScaler().fit_transform(df_bsns_rsk)
df_fncl_rsk = StandardScaler().fit_transform(df_fncl_rsk)

# %%
pca = PCA(n_components=df_liq.shape[1])
pca.fit(df_liq)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]),  
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0       0.86701
# 1       1.00000

# %%
pcs = pca.fit_transform(df_liq)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_liq_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['liq_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 86.701%

# %% [markdown]
# op_prof

# %%
pca = PCA(n_components=df_op_prof.shape[1])
pca.fit(df_op_prof)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]),  
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.942934
# 1      1.000000

# %%
pcs = pca.fit_transform(df_op_prof)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_op_prof_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['op_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 94.293%

# %% [markdown]
# bsns_rsk

# %%
pca = PCA(n_components=df_bsns_rsk.shape[1])
pca.fit(df_bsns_rsk)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.785348
# 1      1.000000

# %%
pcs = pca.fit_transform(df_bsns_rsk)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_bsns_rsk_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['bs_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 78.535%

# %% [markdown]
# fncl_rsk

# %%
pca = PCA(n_components=df_fncl_rsk.shape[1])
pca.fit(df_fncl_rsk)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.938459
# 1      0.991801
# 2      1.000000

# %%
pcs = pca.fit_transform(df_fncl_rsk)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_fncl_rsk_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['fn_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 93.846%

# %% [markdown]
# concatenate

# %%
df_list = [df_liq_pc, df_op_prof_pc,df_bsns_rsk_pc,df_fncl_rsk_pc,df ]
df_full = pd.concat(df_list, ignore_index=False,axis=1)
df_full.head()

# 35개
# Out:
#           liq_1      op_1      bs_1      fn_1  Unnamed: 0     Attr1    Attr2  \
# 0 -5.690372e-02 -0.039632 -0.006127 -0.527226           0 -0.024558  0.30051
# 1  4.056575e-17 -0.097482 -0.038243 -0.412242           1  0.639180  0.00000
# 2 -5.763256e-02 -0.015167  0.006112 -0.194449           2 -0.440760  0.47723
# 3 -2.880104e-03 -0.046792 -0.011557 -0.772702           3  0.119520  0.17679
# 4 -3.597121e-02 -0.068734 -0.023606 -0.562140           4  0.230400  0.27095
#
#      Attr3     Attr4    Attr5  ...    Attr56    Attr57   Attr58   Attr59  \
# 0  0.10733  1.836800   34.382  ...  0.062497 -0.036289  0.93750  0.25454
# 1  1.00000  8.664398   29.678  ...  0.679830  0.639180  0.32014  0.00000
# 2  0.19260  1.467800   34.555  ... -0.290590 -0.843130  1.28710  0.12538
# 3  0.63546  4.594400  117.650  ...  0.112110  0.147520  0.88789  0.00000
# 4  0.23762  2.574500  -26.928  ...  0.459570  0.316020  0.62320  0.16465
#
#        Attr60   Attr61  Attr62   Attr63     Attr64  class
# 0   13.632000   3.6930  69.389  5.26020   0.882600    0.0
# 1  134.817648  37.8860   0.000  8.99491  36.363852    0.0
# 2  134.817648   2.5649  98.950  3.68870   3.837600    0.0
# 3    8.930200  10.2870  40.355  9.04480   8.516900    0.0
# 4    7.927400   6.6605  68.502  5.32830   1.315000    0.0
#
# [5 rows x 69 columns]

# %%
df_full.drop(['Attr4','Attr40','Attr42','Attr49','Attr13','Attr19','Attr10','Attr2','Attr25'],axis=1,inplace=True)

df_full1 = df_full.sample(frac=0.95, random_state=786)
df_full1.reset_index(inplace=True, drop=True)

df_unseen = df_full.drop(df_full1.index)
df_unseen.reset_index(inplace=True, drop=True)

df_full.head()
# Out:
#           liq_1      op_1      bs_1      fn_1  Unnamed: 0     Attr1    Attr3  \
# 0 -5.690372e-02 -0.039632 -0.006127 -0.527226           0 -0.024558  0.10733
# 1  4.056575e-17 -0.097482 -0.038243 -0.412242           1  0.639180  1.00000
# 2 -5.763256e-02 -0.015167  0.006112 -0.194449           2 -0.440760  0.19260
# 3 -2.880104e-03 -0.046792 -0.011557 -0.772702           3  0.119520  0.63546
# 4 -3.597121e-02 -0.068734 -0.023606 -0.562140           4  0.230400  0.23762
#
#      Attr5     Attr6     Attr7  ...    Attr56    Attr57   Attr58   Attr59  \
# 0   34.382 -0.026711 -0.020067  ...  0.062497 -0.036289  0.93750  0.25454
# 1   29.678 -1.139300  0.760520  ...  0.679830  0.639180  0.32014  0.00000
# 2   34.555  0.000000 -0.440760  ... -0.290590 -0.843130  1.28710  0.12538
# 3  117.650  0.251540  0.148750  ...  0.112110  0.147520  0.88789  0.00000
# 4  -26.928  0.617540  0.282690  ...  0.459570  0.316020  0.62320  0.16465
#
#        Attr60   Attr61  Attr62   Attr63     Attr64  class
# 0   13.632000   3.6930  69.389  5.26020   0.882600    0.0
# 1  134.817648  37.8860   0.000  8.99491  36.363852    0.0
# 2  134.817648   2.5649  98.950  3.68870   3.837600    0.0
# 3    8.930200  10.2870  40.355  9.04480   8.516900    0.0
# 4    7.927400   6.6605  68.502  5.32830   1.315000    0.0
#
# [5 rows x 60 columns]

# %%
df_unseen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 60 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   liq_1       341 non-null    float64
#  1   op_1        341 non-null    float64
#  2   bs_1        341 non-null    float64
#  3   fn_1        341 non-null    float64
#  4   Unnamed: 0  341 non-null    int64
#  5   Attr1       341 non-null    float64
#  6   Attr3       341 non-null    float64
#  7   Attr5       341 non-null    float64
#  8   Attr6       341 non-null    float64
#  9   Attr7       341 non-null    float64
#  10  Attr8       341 non-null    float64
#  11  Attr9       341 non-null    float64
#  12  Attr11      341 non-null    float64
#  13  Attr12      341 non-null    float64
#  14  Attr14      341 non-null    float64
#  15  Attr15      341 non-null    float64
#  16  Attr16      341 non-null    float64
#  17  Attr17      341 non-null    float64
#  18  Attr18      341 non-null    float64
#  19  Attr20      341 non-null    float64
#  20  Attr21      341 non-null    float64
#  21  Attr22      341 non-null    float64
#  22  Attr23      341 non-null    float64
#  23  Attr24      341 non-null    float64
#  24  Attr26      341 non-null    float64
#  25  Attr27      341 non-null    float64
#  26  Attr28      341 non-null    float64
#  27  Attr29      341 non-null    float64
#  28  Attr30      341 non-null    float64
#  29  Attr31      341 non-null    float64
#  30  Attr32      341 non-null    float64
#  31  Attr33      341 non-null    float64
#  32  Attr34      341 non-null    float64
#  33  Attr35      341 non-null    float64
#  34  Attr36      341 non-null    float64
#  35  Attr38      341 non-null    float64
#  36  Attr39      341 non-null    float64
#  37  Attr41      341 non-null    float64
#  38  Attr43      341 non-null    float64
#  39  Attr44      341 non-null    float64
#  40  Attr45      341 non-null    float64
#  41  Attr46      341 non-null    float64
#  42  Attr47      341 non-null    float64
#  43  Attr48      341 non-null    float64
#  44  Attr50      341 non-null    float64
#  45  Attr51      341 non-null    float64
#  46  Attr52      341 non-null    float64
#  47  Attr53      341 non-null    float64
#  48  Attr54      341 non-null    float64
#  49  Attr55      341 non-null    float64
#  50  Attr56      341 non-null    float64
#  51  Attr57      341 non-null    float64
#  52  Attr58      341 non-null    float64
#  53  Attr59      341 non-null    float64
#  54  Attr60      341 non-null    float64
#  55  Attr61      341 non-null    float64
#  56  Attr62      341 non-null    float64
#  57  Attr63      341 non-null    float64
#  58  Attr64      341 non-null    float64
#  59  class       341 non-null    float64
# dtypes: float64(59), int64(1)
# memory usage: 160.0 KB

# %%
from pycaret.classification import *

exp_name = setup(data = df_full1,  target = 'class',train_size=0.9, data_split_shuffle = True, 
                 fold_strategy='stratifiedkfold', fold=10, 
                 silent = True, verbose = False, session_id = 123)

# %%
best_model = compare_models(sort='F1')
# Out:
# <style  type="text/css" >
#     #T_822ad_ th {
#           text-align: left;
#     }#T_822ad_row0_col0,#T_822ad_row0_col3,#T_822ad_row1_col0,#T_822ad_row1_col1,#T_822ad_row1_col2,#T_822ad_row1_col3,#T_822ad_row1_col4,#T_822ad_row1_col5,#T_822ad_row1_col6,#T_822ad_row1_col7,#T_822ad_row2_col0,#T_822ad_row2_col1,#T_822ad_row2_col2,#T_822ad_row2_col3,#T_822ad_row2_col4,#T_822ad_row2_col5,#T_822ad_row2_col6,#T_822ad_row2_col7,#T_822ad_row3_col0,#T_822ad_row3_col1,#T_822ad_row3_col2,#T_822ad_row3_col3,#T_822ad_row3_col4,#T_822ad_row3_col5,#T_822ad_row3_col6,#T_822ad_row3_col7,#T_822ad_row4_col0,#T_822ad_row4_col1,#T_822ad_row4_col2,#T_822ad_row4_col3,#T_822ad_row4_col4,#T_822ad_row4_col5,#T_822ad_row4_col6,#T_822ad_row4_col7,#T_822ad_row5_col0,#T_822ad_row5_col1,#T_822ad_row5_col2,#T_822ad_row5_col3,#T_822ad_row5_col4,#T_822ad_row5_col5,#T_822ad_row5_col6,#T_822ad_row5_col7,#T_822ad_row6_col0,#T_822ad_row6_col1,#T_822ad_row6_col2,#T_822ad_row6_col3,#T_822ad_row6_col4,#T_822ad_row6_col5,#T_822ad_row6_col6,#T_822ad_row6_col7,#T_822ad_row7_col0,#T_822ad_row7_col1,#T_822ad_row7_col2,#T_822ad_row7_col4,#T_822ad_row7_col5,#T_822ad_row7_col6,#T_822ad_row7_col7,#T_822ad_row8_col0,#T_822ad_row8_col1,#T_822ad_row8_col2,#T_822ad_row8_col3,#T_822ad_row8_col4,#T_822ad_row8_col5,#T_822ad_row8_col6,#T_822ad_row8_col7,#T_822ad_row9_col0,#T_822ad_row9_col1,#T_822ad_row9_col2,#T_822ad_row9_col3,#T_822ad_row9_col4,#T_822ad_row9_col5,#T_822ad_row9_col6,#T_822ad_row9_col7,#T_822ad_row10_col0,#T_822ad_row10_col1,#T_822ad_row10_col2,#T_822ad_row10_col3,#T_822ad_row10_col4,#T_822ad_row10_col5,#T_822ad_row10_col6,#T_822ad_row10_col7,#T_822ad_row11_col0,#T_822ad_row11_col1,#T_822ad_row11_col2,#T_822ad_row11_col3,#T_822ad_row11_col4,#T_822ad_row11_col5,#T_822ad_row11_col6,#T_822ad_row11_col7,#T_822ad_row12_col0,#T_822ad_row12_col1,#T_822ad_row12_col2,#T_822ad_row12_col3,#T_822ad_row12_col4,#T_822ad_row12_col5,#T_822ad_row12_col6,#T_822ad_row12_col7,#T_822ad_row13_col0,#T_822ad_row13_col1,#T_822ad_row13_col2,#T_822ad_row13_col3,#T_822ad_row13_col4,#T_822ad_row13_col5,#T_822ad_row13_col6,#T_822ad_row13_col7,#T_822ad_row14_col0,#T_822ad_row14_col1,#T_822ad_row14_col2,#T_822ad_row14_col3,#T_822ad_row14_col4,#T_822ad_row14_col5,#T_822ad_row14_col6,#T_822ad_row14_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_822ad_row0_col1,#T_822ad_row0_col2,#T_822ad_row0_col4,#T_822ad_row0_col5,#T_822ad_row0_col6,#T_822ad_row0_col7,#T_822ad_row7_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_822ad_row0_col8,#T_822ad_row1_col8,#T_822ad_row2_col8,#T_822ad_row3_col8,#T_822ad_row4_col8,#T_822ad_row5_col8,#T_822ad_row6_col8,#T_822ad_row7_col8,#T_822ad_row8_col8,#T_822ad_row9_col8,#T_822ad_row10_col8,#T_822ad_row12_col8,#T_822ad_row13_col8,#T_822ad_row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_822ad_row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_822ad_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_822ad_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_822ad_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_822ad_row0_col1" class="data row0 col1" >0.9679</td>
#                         <td id="T_822ad_row0_col2" class="data row0 col2" >0.9348</td>
#                         <td id="T_822ad_row0_col3" class="data row0 col3" >0.3916</td>
#                         <td id="T_822ad_row0_col4" class="data row0 col4" >0.9212</td>
#                         <td id="T_822ad_row0_col5" class="data row0 col5" >0.5451</td>
#                         <td id="T_822ad_row0_col6" class="data row0 col6" >0.5316</td>
#                         <td id="T_822ad_row0_col7" class="data row0 col7" >0.5863</td>
#                         <td id="T_822ad_row0_col8" class="data row0 col8" >6.8180</td>
#             </tr>
#             <tr>
#                         <th id="T_822ad_level0_row1" class="row_heading level0 row1" >xgboost</th>
#                         <td id="T_822ad_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_822ad_row1_col1" class="data row1 col1" >0.9669</td>
#                         <td id="T_822ad_row1_col2" class="data row1 col2" >0.9247</td>
#                         <td id="T_822ad_row1_col3" class="data row1 col3" >0.3846</td>
#                         <td id="T_822ad_row1_col4" class="data row1 col4" >0.8945</td>
#                         <td id="T_822ad_row1_col5" class="data row1 col5" >0.5346</td>
#                         <td id="T_822ad_row1_col6" class="data row1 col6" >0.5204</td>
#                         <td id="T_822ad_row1_col7" class="data row1 col7" >0.5722</td>
#                         <td id="T_822ad_row1_col8" class="data row1 col8" >1.3510</td>
#             </tr>
#             <tr>
#                         <th id="T_822ad_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#                         <td id="T_822ad_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_822ad_row2_col1" class="data row2 col1" >0.9669</td>
#                         <td id="T_822ad_row2_col2" class="data row2 col2" >0.9211</td>
#                         <td id="T_822ad_row2_col3" class="data row2 col3" >0.3777</td>
#                         <td id="T_822ad_row2_col4" class="data row2 col4" >0.8997</td>
#                         <td id="T_822ad_row2_col5" class="data row2 col5" >0.5295</td>
#                         <td id="T_822ad_row2_col6" class="data row2 col6" >0.5155</td>
#                         <td id="T_822ad_row2_col7" class="data row2 col7" >0.5694</td>
#                         <td id="T_822ad_row2_col8" class="data row2 col8" >0.3830</td>
#             </tr>
#             <tr>
#                         <th id="T_822ad_level0_row3" class="row_heading level0 row3" >gbc</th>
#                         <td id="T_822ad_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_822ad_row3_col1" class="data row3 col1" >0.9630</td>
#                         <td id="T_822ad_row3_col2" class="data row3 col2" >0.9065</td>
#                         <td id="T_822ad_row3_col3" class="data row3 col3" >0.3193</td>
#                         <td id="T_822ad_row3_col4" class="data row3 col4" >0.8479</td>
#                         <td id="T_822ad_row3_col5" class="data row3 col5" >0.4596</td>
#                         <td id="T_822ad_row3_col6" class="data row3 col6" >0.4446</td>
#                         <td id="T_822ad_row3_col7" class="data row3 col7" >0.5041</td>
#                         <td id="T_822ad_row3_col8" class="data row3 col8" >1.6170</td>
#             </tr>
#             <tr>
#                         <th id="T_822ad_level0_row4" class="row_heading level0 row4" >dt</th>
#                         <td id="T_822ad_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#                         <td id="T_822ad_row4_col1" class="data row4 col1" >0.9316</td>
#                         <td id="T_822ad_row4_col2" class="data row4 col2" >0.6674</td>
#                         <td id="T_822ad_row4_col3" class="data row4 col3" >0.3740</td>
#                         <td id="

# %% [markdown]
# # catboost!

# %%
catboost = create_model('catboost')
tuned_catboost = tune_model(catboost)
# Out:
# <style  type="text/css" >
# #T_6e5ee_row10_col0,#T_6e5ee_row10_col1,#T_6e5ee_row10_col2,#T_6e5ee_row10_col3,#T_6e5ee_row10_col4,#T_6e5ee_row10_col5,#T_6e5ee_row10_col6{
#             background:  yellow;
#         }</style><table id="T_6e5ee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e5ee_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e5ee_row0_col0" class="data row0 col0" >0.9743</td>
#                         <td id="T_6e5ee_row0_col1" class="data row0 col1" >0.9167</td>
#                         <td id="T_6e5ee_row0_col2" class="data row0 col2" >0.5667</td>
#                         <td id="T_6e5ee_row0_col3" class="data row0 col3" >0.8947</td>
#                         <td id="T_6e5ee_row0_col4" class="data row0 col4" >0.6939</td>
#                         <td id="T_6e5ee_row0_col5" class="data row0 col5" >0.6812</td>
#                         <td id="T_6e5ee_row0_col6" class="data row0 col6" >0.7006</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6e5ee_row1_col0" class="data row1 col0" >0.9657</td>
#                         <td id="T_6e5ee_row1_col1" class="data row1 col1" >0.8895</td>
#                         <td id="T_6e5ee_row1_col2" class="data row1 col2" >0.3103</td>
#                         <td id="T_6e5ee_row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_6e5ee_row1_col4" class="data row1 col4" >0.4737</td>
#                         <td id="T_6e5ee_row1_col5" class="data row1 col5" >0.4610</td>
#                         <td id="T_6e5ee_row1_col6" class="data row1 col6" >0.5473</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6e5ee_row2_col0" class="data row2 col0" >0.9691</td>
#                         <td id="T_6e5ee_row2_col1" class="data row2 col1" >0.9089</td>
#                         <td id="T_6e5ee_row2_col2" class="data row2 col2" >0.4483</td>
#                         <td id="T_6e5ee_row2_col3" class="data row2 col3" >0.8667</td>
#                         <td id="T_6e5ee_row2_col4" class="data row2 col4" >0.5909</td>
#                         <td id="T_6e5ee_row2_col5" class="data row2 col5" >0.5765</td>
#                         <td id="T_6e5ee_row2_col6" class="data row2 col6" >0.6106</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6e5ee_row3_col0" class="data row3 col0" >0.9743</td>
#                         <td id="T_6e5ee_row3_col1" class="data row3 col1" >0.9209</td>
#                         <td id="T_6e5ee_row3_col2" class="data row3 col2" >0.5172</td>
#                         <td id="T_6e5ee_row3_col3" class="data row3 col3" >0.9375</td>
#                         <td id="T_6e5ee_row3_col4" class="data row3 col4" >0.6667</td>
#                         <td id="T_6e5ee_row3_col5" class="data row3 col5" >0.6544</td>
#                         <td id="T_6e5ee_row3_col6" class="data row3 col6" >0.6859</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6e5ee_row4_col0" class="data row4 col0" >0.9691</td>
#                         <td id="T_6e5ee_row4_col1" class="data row4 col1" >0.9795</td>
#                         <td id="T_6e5ee_row4_col2" class="data row4 col2" >0.4828</td>
#                         <td id="T_6e5ee_row4_col3" class="data row4 col3" >0.8235</td>
#                         <td id="T_6e5ee_row4_col4" class="data row4 col4" >0.6087</td>
#                         <td id="T_6e5ee_row4_col5" class="data row4 col5" >0.5938</td>
#                         <td id="T_6e5ee_row4_col6" class="data row4 col6" >0.6168</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6e5ee_row5_col0" class="data row5 col0" >0.9674</td>
#                         <td id="T_6e5ee_row5_col1" class="data row5 col1" >0.9191</td>
#                         <td id="T_6e5ee_row5_col2" class="data row5 col2" >0.3793</td>
#                         <td id="T_6e5ee_row5_col3" class="data row5 col3" >0.9167</td>
#                         <td id="T_6e5ee_row5_col4" class="data row5 col4" >0.5366</td>
#                         <td id="T_6e5ee_row5_col5" class="data row5 col5" >0.5227</td>
#                         <td id="T_6e5ee_row5_col6" class="data row5 col6" >0.5781</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6e5ee_row6_col0" class="data row6 col0" >0.9708</td>
#                         <td id="T_6e5ee_row6_col1" class="data row6 col1" >0.9533</td>
#                         <td id="T_6e5ee_row6_col2" class="data row6 col2" >0.4138</td>
#                         <td id="T_6e5ee_row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_6e5ee_row6_col4" class="data row6 col4" >0.5854</td>
#                         <td id="T_6e5ee_row6_col5" class="data row6 col5" >0.5729</td>
#                         <td id="T_6e5ee_row6_col6" class="data row6 col6" >0.6336</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6e5ee_row7_col0" class="data row7 col0" >0.9640</td>
#                         <td id="T_6e5ee_row7_col1" class="data row7 col1" >0.9003</td>
#                         <td id="T_6e5ee_row7_col2" class="data row7 col2" >0.3103</td>
#                         <td id="T_6e5ee_row7_col3" class="data row7 col3" >0.9000</td>
#                         <td id="T_6e5ee_row7_col4" class="data row7 col4" >0.4615</td>
#                         <td id="T_6e5ee_row7_col5" class="data row7 col5" >0.4474</td>
#                         <td id="T_6e5ee_row7_col6" class="data row7 col6" >0.5166</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6e5ee_row8_col0" class="data row8 col0" >0.9726</td>
#                         <td id="T_6e5ee_row8_col1" class="data row8 col1" >0.9393</td>
#                         <td id="T_6e5ee_row8_col2" class="data row8 col2" >0.4828</td>
#                         <td id="T_6e5ee_row8_col3" class="data row8 col3" >0.9333</td>
#                         <td id="T_6e5ee_row8_col4" class="data row8 col4" >0.6364</td>
#                         <td id="T_6e5ee_row8_col5" class="data row8 col5" >0.6236</td>
#                         <td id="T_6e5ee_row8_col6" class="data row8 col6" >0.6604</td>
#             </tr>
#             <tr>
#                         <th id="T_6e5ee_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6e5ee_row9_col0" class="data row9 col0" >0.9657</td>
#                         <td id="T_6e5ee_row9_col1" class="data row9 col1" >0.9170</td>
#                         <td id="T_6e5ee_row9_col2" class="data row9 col2" >0.3448</td>
#                         <td id="T_6e5ee_row9_col3" class="data row9 col3" >0.9091</td>
#                         <td id="T_6e5ee_row9_col4" class="data row9 col4" >0.5000</td>
#                         <td id="T_6e5ee_row9_col5" class="data row9 col5" >0.4859</td>
#                         <td id=

# %%
final_catboost = finalize_model(tuned_catboost)

# %%
unseen_predictions = predict_model(final_catboost, data=df_unseen)
unseen_predictions.head()
# Out:
#       liq_1      op_1      bs_1      fn_1  Unnamed: 0     Attr1     Attr3  \
# 0  0.010202 -0.044038 -0.012016 -0.983518        6513  0.052013  0.605560
# 1 -0.057800 -0.043068 -0.007270  0.106401        6514  0.004142  0.004794
# 2 -0.048837 -0.052328 -0.013823 -0.345820        6515  0.288930  0.713730
# 3 -0.057284 -0.044175 -0.009534  1.534975        6516  0.156330 -0.392060
# 4 -0.051659 -0.042144 -0.009554 -0.478918        6517  0.090630  0.324490
#
#       Attr5    Attr6     Attr7  ...   Attr58   Attr59  Attr60   Attr61  \
# 0  146.1800  0.18688  0.066273  ...  0.91819  0.00000  1.8966   5.2606
# 1 -202.0200 -0.19273 -0.006737  ...  0.62859  0.45777  3.7113  14.7030
# 2   14.5830  0.00000  0.360730  ...  0.85094  0.33994  3.7709   9.6891
# 3 -101.3800 -0.72018  0.156330  ...  0.94250  0.00000  8.6625   5.4105
# 4    1.8897 -0.34409  0.090630  ...  0.96172  0.00000  7.3060   9.6249
#
#     Attr62   Attr63   Attr64  class  Label   Score
# 0   36.290  10.0580   2.0671    0.0    0.0  0.9991
# 1  131.190   2.7822   1.6533    0.0    0.0  0.9766
# 2   28.152  12.9650  23.1320    0.0    0.0  0.9834
# 3  192.390   1.8972  53.3770    0.0    0.0  0.9857
# 4   50.489   7.2293   6.2599    0.0    0.0  0.9979
#
# [5 rows x 62 columns]

# %%
from pycaret.utils import version, check_metric
check_metric(unseen_predictions['class'],unseen_predictions['Label'].astype('float32'), metric = 'F1')
# Out:
# 0.6957

# %%
df_unseen['class'].value_counts()
# Out:
# 0.0    326
# 1.0     15
# Name: class, dtype: int64

# %% [markdown]
# # 정리
#
# 기본적으로 'catboost!' 전에는 동일, (즉 전처리, PCA 등이 동일, 기본 setting과 compared까지)
#
# 추가적으로 tuned하기 위해 catboost만 추가 진행하였다고 보면 됨. modeling_jcpark_v2에 catboost만 이어서 했다는 느낌.
#
# 결과는 위와 같음.
#
# unseen_predictions는 f1 score 는 0.6957이 나옴
