# %%
# !pip install pycaret
# !pip install pyyaml==5.4.1
# !pip install plotly --upgrade
# !pip install shap --upgrade
# !pip install interpret
# !pip install interpret-community

# %%
# !pip install -U pandas-profiling

# %%
import pandas as pd
import pandas_profiling
import numpy as np
import seaborn as sns
from pandas_profiling import ProfileReport
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Escfinal/feature_extraction.csv',encoding='utf-8')
#df_label = pd.read_csv('',encoding='utf-8')
#df = pd.merge(df,df_label,on='id')
#df = df.astype({'class':'category'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6820 entries, 0 to 6819
# Data columns (total 43 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   6820 non-null   float64
#  1   Attr2   6820 non-null   float64
#  2   Attr3   6820 non-null   float64
#  3   Attr4   6820 non-null   float64
#  4   Attr5   6820 non-null   float64
#  5   Attr6   6820 non-null   float64
#  6   Attr7   6820 non-null   float64
#  7   Attr8   6820 non-null   float64
#  8   Attr9   6820 non-null   float64
#  9   Attr10  6820 non-null   float64
#  10  Attr12  6820 non-null   float64
#  11  Attr13  6820 non-null   float64
#  12  Attr15  6820 non-null   float64
#  13  Attr18  6820 non-null   float64
#  14  Attr19  6820 non-null   float64
#  15  Attr20  6820 non-null   float64
#  16  Attr21  6820 non-null   float64
#  17  Attr24  6820 non-null   float64
#  18  Attr25  6820 non-null   float64
#  19  Attr27  6820 non-null   float64
#  20  Attr28  6820 non-null   float64
#  21  Attr29  6820 non-null   float64
#  22  Attr30  6820 non-null   float64
#  23  Attr32  6820 non-null   float64
#  24  Attr33  6820 non-null   float64
#  25  Attr38  6820 non-null   float64
#  26  Attr39  6820 non-null   float64
#  27  Attr40  6820 non-null   float64
#  28  Attr41  6820 non-null   float64
#  29  Attr42  6820 non-null   float64
#  30  Attr43  6820 non-null   float64
#  31  Attr45  6820 non-null   float64
#  32  Attr47  6820 non-null   float64
#  33  Attr49  6820 non-null   float64
#  34  Attr51  6820 non-null   float64
#  35  Attr53  6820 non-null   float64
#  36  Attr55  6820 non-null   float64
#  37  Attr57  6820 non-null   float64
#  38  Attr58  6820 non-null   float64
#  39  Attr59  6820 non-null   float64
#  40  Attr61  6820 non-null   float64
#  41  Attr64  6820 non-null   float64
#  42  class   6820 non-null   int64
# dtypes: float64(42), int64(1)
# memory usage: 2.2 MB

# %% [markdown]
# # clustering variables + PCA

# %%
df_liq = df[['Attr12','Attr32','Attr33','Attr4','Attr40','Attr5']]
df_tn_ovr = df[['Attr1','Attr15','Attr20','Attr43','Attr47','Attr57','Attr61','Attr64']]
df_op_prof = df[['Attr18','Attr21','Attr24','Attr27','Attr3','Attr41','Attr42','Attr45','Attr49','Attr53','Attr7']]
df_bsns_rsk = df[['Attr13','Attr19','Attr39']]
df_fncl_rsk = df[['Attr10','Attr2','Attr25','Attr30','Attr58','Attr59','Attr6','Attr8']]
df_stab = df[['Attr28','Attr29','Attr38','Attr55']]

# %%
from sklearn.preprocessing import StandardScaler
df_liq = StandardScaler().fit_transform(df_liq)
df_tn_ovr = StandardScaler().fit_transform(df_tn_ovr)
df_op_prof = StandardScaler().fit_transform(df_op_prof)
df_bsns_rsk = StandardScaler().fit_transform(df_bsns_rsk)
df_fncl_rsk = StandardScaler().fit_transform(df_fncl_rsk)
df_stab = StandardScaler().fit_transform(df_stab)

# %%
pca = PCA(n_components=df_liq.shape[1])
pca.fit(df_liq)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]),  
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.363323
# 1      0.545178
# 2      0.719125
# 3      0.878379
# 4      0.961137
# 5      1.000000

# %%
pcs = pca.fit_transform(df_liq)
n_of_pcs = 5
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_liq_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['liq_1','liq_2','liq_3','liq_4','liq_5'][:n_of_pcs])
# Out:
# PC의 설명력 : 96.114%

# %%
df_liq_pc.head()
# Out:
#       liq_1     liq_2     liq_3     liq_4     liq_5
# 0 -0.077698 -0.009744  0.036172 -0.045073 -0.015530
# 1  0.000312  0.001476  0.050332 -0.061983 -0.000834
# 2 -0.088944 -0.019859  0.035746 -0.044869 -0.002328
# 3 -0.007213 -0.003145  0.045225 -0.047667 -0.006670
# 4 -0.045926 -0.010120  0.021055 -0.036718 -0.060496

# %% [markdown]
# tnovr

# %%
pca = PCA(n_components=df_tn_ovr.shape[1])
pca.fit(df_tn_ovr)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.160328
# 1      0.293981
# 2      0.419833
# 3      0.545047
# 4      0.669945
# 5      0.794105
# 6      0.910220
# 7      1.000000

# %%
pcs = pca.fit_transform(df_tn_ovr)
n_of_pcs = 8
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_tn_ovr_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['tn_1','tn_2','tn_3','tn_4','tn_5','tn_6','tn_7','tn_8'][:n_of_pcs])
# Out:
# PC의 설명력 : 100.000%

# %% [markdown]
# op_prof

# %%
pca = PCA(n_components=df_op_prof.shape[1])
pca.fit(df_op_prof)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]),  
                    columns=['Cum_V_ration'])
# Out:
#     Cum_V_ration
# 0       0.181367
# 1       0.349062
# 2       0.444868
# 3       0.536316
# 4       0.627254
# 5       0.717696
# 6       0.807627
# 7       0.889788
# 8       0.961332
# 9       0.989714
# 10      1.000000

# %%
pcs = pca.fit_transform(df_op_prof)
n_of_pcs = 9
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_op_prof_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['op_1','op_2','op_3','op_4','op_5','op_6','op_7','op_8','op_9'][:n_of_pcs])
# Out:
# PC의 설명력 : 96.133%

# %% [markdown]
# bsns_rsk

# %%
pca = PCA(n_components=df_bsns_rsk.shape[1])
pca.fit(df_bsns_rsk)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.530467
# 1      0.869240
# 2      1.000000

# %%
pcs = pca.fit_transform(df_bsns_rsk)
n_of_pcs = 3
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_bsns_rsk_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['bs_1','bs_2','bs_3'][:n_of_pcs])
# Out:
# PC의 설명력 : 100.000%

# %% [markdown]
# fncl_rsk

# %%
pca = PCA(n_components=df_fncl_rsk.shape[1])
pca.fit(df_fncl_rsk)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.366892
# 1      0.498122
# 2      0.623147
# 3      0.748038
# 4      0.867048
# 5      0.977412
# 6      0.996930
# 7      1.000000

# %%
pcs = pca.fit_transform(df_fncl_rsk)
n_of_pcs = 6
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_fncl_rsk_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['fn_1','fn_2','fn_3','fn_4','fn_5','fn_6'][:n_of_pcs])
# Out:
# PC의 설명력 : 97.741%

# %% [markdown]
# stab

# %%
pca = PCA(n_components=df_stab.shape[1])
pca.fit(df_stab)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.313673
# 1      0.565597
# 2      0.805541
# 3      1.000000

# %%
pcs = pca.fit_transform(df_stab)
n_of_pcs = 4
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_stab_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['stb_1','stb_2','stb_3','stb_4'][:n_of_pcs])
# Out:
# PC의 설명력 : 100.000%

# %% [markdown]
# concatenate

# %%
df_label = df[['class']]
df_list = [df_liq_pc, df_tn_ovr_pc, df_op_prof_pc,df_bsns_rsk_pc,df_fncl_rsk_pc,df_stab_pc,df_label]
df_full = pd.concat(df_list, ignore_index=False,axis=1)
df_full.head()
# 35개
# Out:
#       liq_1     liq_2     liq_3     liq_4  ...     stb_2     stb_3     stb_4  class
# 0 -0.077698 -0.009744  0.036172 -0.045073  ...  0.055985 -0.333463 -0.361790      0
# 1  0.000312  0.001476  0.050332 -0.061983  ...  0.389720 -0.465096  2.539435      0
# 2 -0.088944 -0.019859  0.035746 -0.044869  ...  0.060304 -0.109277  0.817294      0
# 3 -0.007213 -0.003145  0.045225 -0.047667  ... -0.216331  1.022179 -0.119245      0
# 4 -0.045926 -0.010120  0.021055 -0.036718  ... -0.123421 -0.382468 -2.707671      0
#
# [5 rows x 36 columns]

# %% [markdown]
# # 머신러닝 기반 전반적인 model accuracy 확인
#
# 데이터셋에 적합한 모델을 찾기 위해 13개 베이스 모델에 대해 성능 찍어봄. stratified k fold 10으로 train size 0.9로 진행. Gradient Boosting Classifier 에서 Accuracy 0.6951로 가장 높았고, F1 score는 Light Gradient Boosting Machine이 0.6823로 가장 높았음.
#
# 원 데이터보다 약 3% 낮아 차이가 있었음.
#
# 전처리 데이터가 변수를 30%만 사용했음에도 불구하고 데이터 정보량을 잘 보존했다고 보여짐

# %%
from pycaret.classification import *

exp_name = setup(data = df_full,  target = 'class',train_size=0.9, data_split_shuffle = True, 
                 fold_strategy='stratifiedkfold', fold=10, 
                 silent = True, verbose = False, session_id = 123)

# %%
# from pycaret.classification import *

# exp_name = setup(data = df_full,  target = 'class',session_id=2021)

# %%
best_model = compare_models(sort='F1')
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# dt               Decision Tree Classifier    0.8910  0.5460  0.1587  0.1231
# lightgbm  Light Gradient Boosting Machine    0.9431  0.7896  0.0630  0.3915
# qda       Quadratic Discriminant Analysis    0.1412  0.4975  0.9015  0.0545
# ada                  Ada Boost Classifier    0.9428  0.7497  0.0601  0.3644
# nb                            Naive Bayes    0.0963  0.6101  0.9405  0.0539
# knn                K Neighbors Classifier    0.9423  0.6123  0.0330  0.3033
# gbc          Gradient Boosting Classifier    0.9417  0.7863  0.0239  0.2867
# svm                   SVM - Linear Kernel    0.9125  0.0000  0.0242  0.0808
# et                 Extra Trees Classifier    0.9420  0.7383  0.0120  0.1500
# lda          Linear Discriminant Analysis    0.9420  0.7025  0.0119  0.1400
# lr                    Logistic Regression    0.9428  0.6718  0.0089  0.0867
# ridge                    Ridge Classifier    0.9444  0.0000  0.0059  0.0833
# rf               Random Forest Classifier    0.9431  0.7571  0.0029  0.0500
# dummy                    Dummy Classifier    0.9454  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# dt        0.1380  0.0813  0.0822     0.246
# lightgbm  0.1061  0.0923  0.1356     0.613
# qda       0.1028 -0.0001 -0.0017     0.035
# ada       0.1023  0.0882  0.1288     1.070
# nb        0.1020 -0.0014 -0.0124     0.025
# knn       0.0587  0.0474  0.0819     0.315
# gbc       0.0430  0.0323  0.0635     4.699
# svm       0.0312  0.0038  0.0046     0.034
# et        0.0222  0.0139  0.0278     0.961
# lda       0.0217  0.0133  0.0260     0.056
# lr        0.0161  0.0097  0.0160     0.423
# ridge     0.0110  0.0079  0.0148     0.022
# rf        0.0056  0.0008  0.0021     2.193
# dummy     0.0000  0.0000  0.0000     0.020

# %% [markdown]
# # 묶는거 다시

# %%
df_liq = df[['Attr12','Attr32','Attr33','Attr4','Attr40','Attr5']]
df_tn_ovr = df[['Attr1','Attr15','Attr20','Attr43','Attr47','Attr57','Attr61','Attr64']]
df_op_prof = df[['Attr18','Attr21','Attr24','Attr27','Attr3','Attr41','Attr42','Attr45','Attr49','Attr53','Attr7']]
df_bsns_rsk = df[['Attr13','Attr19','Attr39']]
df_fncl_rsk = df[['Attr10','Attr2','Attr25','Attr30','Attr58','Attr59','Attr6','Attr8']]
df_stab = df[['Attr28','Attr29','Attr38','Attr55']]

# %%
from sklearn.preprocessing import StandardScaler
df_liq = StandardScaler().fit_transform(df_liq)
df_tn_ovr = StandardScaler().fit_transform(df_tn_ovr)
df_op_prof = StandardScaler().fit_transform(df_op_prof)
df_bsns_rsk = StandardScaler().fit_transform(df_bsns_rsk)
df_fncl_rsk = StandardScaler().fit_transform(df_fncl_rsk)
df_stab = StandardScaler().fit_transform(df_stab)

# %%
corr_diff = [abs(df_liq.corr(method='pearson')) > 0.5]
corr_diff[0]
# Out:
#         Attr12  Attr32  Attr33  Attr4  Attr40  Attr5
# Attr12    True   False   False  False   False  False
# Attr32   False    True   False  False   False  False
# Attr33   False   False    True  False   False  False
# Attr4    False   False   False   True    True  False
# Attr40   False   False   False   True    True  False
# Attr5    False   False   False  False   False   True

# %%
corr_diff = [abs(df_tn_ovr.corr(method='pearson')) > 0.5]
corr_diff[0]
# Out:
#         Attr1  Attr15  Attr20  Attr43  Attr47  Attr57  Attr61  Attr64
# Attr1    True   False   False   False   False   False   False   False
# Attr15  False    True   False   False   False   False   False   False
# Attr20  False   False    True   False   False   False   False   False
# Attr43  False   False   False    True   False   False   False   False
# Attr47  False   False   False   False    True   False   False   False
# Attr57  False   False   False   False   False    True   False   False
# Attr61  False   False   False   False   False   False    True   False
# Attr64  False   False   False   False   False   False   False    True

# %%
corr_diff = [abs(df_op_prof.corr(method='pearson')) > 0.5]
corr_diff[0]
# Out:
#         Attr18  Attr21  Attr24  Attr27  ...  Attr45  Attr49  Attr53  Attr7
# Attr18    True   False   False   False  ...   False   False   False   True
# Attr21   False    True   False   False  ...   False   False   False  False
# Attr24   False   False    True   False  ...   False   False   False  False
# Attr27   False   False   False    True  ...   False   False   False  False
# Attr3    False   False   False   False  ...   False   False   False  False
# Attr41   False   False   False   False  ...   False   False   False  False
# Attr42   False   False   False   False  ...   False    True   False  False
# Attr45   False   False   False   False  ...    True   False   False  False
# Attr49   False   False   False   False  ...   False    True   False  False
# Attr53   False   False   False   False  ...   False   False    True  False
# Attr7     True   False   False   False  ...   False   False   False   True
#
# [11 rows x 11 columns]

# %%
corr_diff = [abs(df_bsns_rsk.corr(method='pearson')) > 0.5]
corr_diff[0]
# Out:
#         Attr13  Attr19  Attr39
# Attr13    True    True   False
# Attr19    True    True   False
# Attr39   False   False    True

# %%
corr_diff = [abs(df_fncl_rsk.corr(method='pearson')) > 0.5]
corr_diff[0]
# Out:
#         Attr10  Attr2  Attr25  Attr30  Attr58  Attr59  Attr6  Attr8
# Attr10    True   True    True   False   False   False  False  False
# Attr2     True   True    True   False   False   False  False  False
# Attr25    True   True    True   False   False   False  False  False
# Attr30   False  False   False    True   False   False  False  False
# Attr58   False  False   False   False    True   False  False  False
# Attr59   False  False   False   False   False    True  False  False
# Attr6    False  False   False   False   False   False   True  False
# Attr8    False  False   False   False   False   False  False   True

# %%
corr_diff = [abs(df_stab.corr(method='pearson')) > 0.5]
corr_diff[0]
# Out:
#         Attr28  Attr29  Attr38  Attr55
# Attr28    True   False   False   False
# Attr29   False    True   False   False
# Attr38   False   False    True   False
# Attr55   False   False   False    True

# %%
df_liq = df[['Attr4','Attr40']]
df_op_prof = df[['Attr42','Attr49']]
df_bsns_rsk = df[['Attr13','Attr19']]
df_fncl_rsk = df[['Attr10','Attr2','Attr25']]

# %%
from sklearn.preprocessing import StandardScaler
df_liq = StandardScaler().fit_transform(df_liq)
#df_tn_ovr = StandardScaler().fit_transform(df_tn_ovr)
df_op_prof = StandardScaler().fit_transform(df_op_prof)
df_bsns_rsk = StandardScaler().fit_transform(df_bsns_rsk)
df_fncl_rsk = StandardScaler().fit_transform(df_fncl_rsk)
#df_stab = StandardScaler().fit_transform(df_stab)

# %% [markdown]
# liq

# %%
pca = PCA(n_components=df_liq.shape[1])
pca.fit(df_liq)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]),  
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0       0.86701
# 1       1.00000

# %%
pcs = pca.fit_transform(df_liq)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_liq_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['liq_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 86.701%

# %%
df_liq_pc.head()

# %% [markdown]
# op_prof

# %%
pca = PCA(n_components=df_op_prof.shape[1])
pca.fit(df_op_prof)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]),  
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.942934
# 1      1.000000

# %%
pcs = pca.fit_transform(df_op_prof)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_op_prof_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['op_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 94.293%

# %%
df_op_prof_pc.head()

# %% [markdown]
# bsns_rsk

# %%
pca = PCA(n_components=df_bsns_rsk.shape[1])
pca.fit(df_bsns_rsk)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.785348
# 1      1.000000

# %%
pcs = pca.fit_transform(df_bsns_rsk)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_bsns_rsk_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['bs_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 78.535%

# %%
df_bsns_rsk_pc.head()

# %% [markdown]
# fncl_rsk

# %%
pca = PCA(n_components=df_fncl_rsk.shape[1])
pca.fit(df_fncl_rsk)
explained_variance_ratio = pca.explained_variance_ratio_
pd.DataFrame(np.cumsum(explained_variance_ratio[:]), 
                    columns=['Cum_V_ration'])
# Out:
#    Cum_V_ration
# 0      0.938459
# 1      0.991801
# 2      1.000000

# %%
pcs = pca.fit_transform(df_fncl_rsk)
n_of_pcs = 1
print("PC의 설명력 : {:.3f}%".format(np.sum(explained_variance_ratio[:n_of_pcs]*100)))
df_fncl_rsk_pc = pd.DataFrame(pcs[:,:n_of_pcs], 
                        columns = ['fn_1'][:n_of_pcs])
# Out:
# PC의 설명력 : 93.846%

# %%
df_fncl_rsk_pc.head()

# %% [markdown]
# concatenate

# %%
df_list = [df_liq_pc, df_op_prof_pc,df_bsns_rsk_pc,df_fncl_rsk_pc,df ]
df_full = pd.concat(df_list, ignore_index=False,axis=1)
df_full.head()
# 35개
# Out:
#           liq_1      op_1      bs_1  ...   Attr61     Attr64  class
# 0 -5.690372e-02 -0.039632 -0.006127  ...   3.6930   0.882600      0
# 1 -6.312333e-12 -0.097482 -0.038243  ...  37.8860  36.363852      0
# 2 -5.763256e-02 -0.015167  0.006112  ...   2.5649   3.837600      0
# 3 -2.880104e-03 -0.046792 -0.011557  ...  10.2870   8.516900      0
# 4 -3.597121e-02 -0.068734 -0.023606  ...   6.6605   1.315000      0
#
# [5 rows x 47 columns]

# %%
df_full.drop(['Attr4','Attr40','Attr42','Attr49','Attr13','Attr19','Attr10','Attr2','Attr25'],axis=1,inplace=True)
df_full.head()
# Out:
#           liq_1      op_1      bs_1  ...   Attr61     Attr64  class
# 0 -5.690372e-02 -0.039632 -0.006127  ...   3.6930   0.882600      0
# 1 -6.312333e-12 -0.097482 -0.038243  ...  37.8860  36.363852      0
# 2 -5.763256e-02 -0.015167  0.006112  ...   2.5649   3.837600      0
# 3 -2.880104e-03 -0.046792 -0.011557  ...  10.2870   8.516900      0
# 4 -3.597121e-02 -0.068734 -0.023606  ...   6.6605   1.315000      0
#
# [5 rows x 38 columns]

# %%
from pycaret.classification import *

exp_name = setup(data = df_full,  target = 'class',train_size=0.9, data_split_shuffle = True, 
                 fold_strategy='stratifiedkfold', fold=10, 
                 silent = True, verbose = False, session_id = 123)

# %%
best_model = compare_models(sort='F1')
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9642  0.9030  0.3884  0.8306
# gbc          Gradient Boosting Classifier    0.9606  0.8998  0.3194  0.8133
# dt               Decision Tree Classifier    0.9296  0.6532  0.3447  0.3280
# ada                  Ada Boost Classifier    0.9523  0.8425  0.2162  0.6370
# rf               Random Forest Classifier    0.9524  0.8585  0.1377  0.7113
# svm                   SVM - Linear Kernel    0.8152  0.0000  0.2545  0.0868
# nb                            Naive Bayes    0.1122  0.4861  0.9182  0.0513
# knn                K Neighbors Classifier    0.9457  0.6225  0.0406  0.2808
# et                 Extra Trees Classifier    0.9451  0.8035  0.0344  0.2452
# qda       Quadratic Discriminant Analysis    0.9016  0.5101  0.0594  0.0536
# lda          Linear Discriminant Analysis    0.9430  0.7085  0.0219  0.1276
# ridge                    Ridge Classifier    0.9464  0.0000  0.0031  0.0500
# lr                    Logistic Regression    0.9457  0.5903  0.0032  0.0250
# dummy                    Dummy Classifier    0.9480  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.5269  0.5110  0.5523     0.605
# gbc       0.4543  0.4381  0.4920     4.642
# dt        0.3330  0.2962  0.2979     0.218
# ada       0.3167  0.2983  0.3480     1.045
# rf        0.2292  0.2164  0.2978     2.438
# svm       0.1201  0.0521  0.0626     0.035
# nb        0.0971 -0.0015 -0.0120     0.025
# knn       0.0698  0.0594  0.0896     0.155
# et        0.0594  0.0488  0.0747     0.919
# qda       0.0427 -0.0010  0.0021     0.035
# lda       0.0373  0.0250  0.0346     0.055
# ridge     0.0059  0.0022  0.0038     0.023
# lr        0.0057  0.0009 -0.0011     1.009
# dummy     0.0000  0.0000  0.0000     0.019

# %%
lightgbm = create_model('lightgbm')
tuned_lightgbmc = tune_model(lightgbm,optimize='F1')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9658  0.9101  0.4062  0.8667  0.5532  0.5378  0.5799
# 1       0.9691  0.8921  0.4375  0.9333  0.5957  0.5818  0.6274
# 2       0.9593  0.8864  0.2500  0.8889  0.3902  0.3760  0.4592
# 3       0.9642  0.9120  0.4062  0.8125  0.5417  0.5252  0.5596
# 4       0.9658  0.8849  0.3750  0.9231  0.5333  0.5188  0.5763
# 5       0.9593  0.9079  0.3125  0.7692  0.4444  0.4272  0.4745
# 6       0.9577  0.8735  0.3125  0.7143  0.4348  0.4163  0.4551
# 7       0.9593  0.9177  0.3125  0.7692  0.4444  0.4272  0.4745
# 8       0.9625  0.9169  0.2581  1.0000  0.4103  0.3978  0.4983
# 9       0.9674  0.9092  0.4062  0.9286  0.5652  0.5509  0.6023
# Mean    0.9630  0.9011  0.3477  0.8606  0.4913  0.4759  0.5307
# SD      0.0038  0.0147  0.0636  0.0863  0.0699  0.0703  0.0617

# %%
bagged_lightgbm = ensemble_model(lightgbm, method = 'Bagging',optimize='F1')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9674  0.9074  0.4375  0.8750  0.5833  0.5683  0.6056
# 1       0.9674  0.8983  0.4062  0.9286  0.5652  0.5510  0.6024
# 2       0.9593  0.9008  0.2812  0.8182  0.4186  0.4027  0.4655
# 3       0.9658  0.9196  0.4062  0.8667  0.5532  0.5378  0.5799
# 4       0.9642  0.8849  0.3438  0.9167  0.5000  0.4854  0.5492
# 5       0.9658  0.9220  0.4062  0.8667  0.5532  0.5378  0.5799
# 6       0.9577  0.9170  0.2812  0.7500  0.4091  0.3918  0.4433
# 7       0.9642  0.9153  0.3125  1.0000  0.4762  0.4629  0.5487
# 8       0.9543  0.9128  0.1613  0.7143  0.2632  0.2492  0.3255
# 9       0.9657  0.9113  0.3438  1.0000  0.5116  0.4982  0.5760
# Mean    0.9632  0.9089  0.3380  0.8736  0.4834  0.4685  0.5276
# SD      0.0043  0.0108  0.0789  0.0898  0.0926  0.0927  0.0850

# %%
top5 = compare_models(n_select = 5,sort='F1')
tuned_top5 = [tune_model(i,optimize='F1') for i in top5]
blender = blend_models(tuned_top5,optimize='F1')
stacker = stack_models(tuned_top5,optimize='F1')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9609  0.8865  0.2500  1.0000  0.4000  0.3872  0.4900
# 1       0.9625  0.8864  0.4062  0.7647  0.5306  0.5130  0.5410
# 2       0.9495  0.8063  0.1562  0.5556  0.2439  0.2262  0.2763
# 3       0.9528  0.8577  0.2812  0.6000  0.3830  0.3617  0.3901
# 4       0.9577  0.8607  0.2812  0.7500  0.4091  0.3918  0.4433
# 5       0.9511  0.7974  0.1875  0.6000  0.2857  0.2675  0.3172
# 6       0.9544  0.8116  0.1875  0.7500  0.3000  0.2851  0.3608
# 7       0.9609  0.8080  0.3438  0.7857  0.4783  0.4612  0.5042
# 8       0.9511  0.8338  0.1613  0.5556  0.2500  0.2325  0.2813
# 9       0.9527  0.8808  0.2188  0.6364  0.3256  0.3071  0.3550
# Mean    0.9554  0.8429  0.2474  0.6998  0.3606  0.3433  0.3959
# SD      0.0045  0.0339  0.0778  0.1313  0.0914  0.0915  0.0897
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   14:05:39
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  9.4min

# %%
best_f1_model = automl(optimize = 'F1')

# %%
best_f1_model = finalize_model(best_f1_model)

# %%
plot_model(bagged_gbc, plot = 'learning')

# %% [markdown]
# manifold 상에서 feature들이 class 별로 명확히 나누어지지 않는 것을 확인할 수 있다.

# %%
plot_model(bagged_gbc, plot = 'manifold')

# %% [markdown]
# False negative를 특히 잘 못 잡아내는 경향이 있었다.

# %%
 plot_model(bagged_gbc, plot = 'confusion_matrix')

# %%
save_model(bagged_gbc, '/content/drive/MyDrive/Colab Notebooks/투자공학_HW3데이터분석/bag_gbc_model')

# %% [markdown]
# # 예측

# %%
import pandas as pd 
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/투자공학_HW3데이터분석/minmax_loan_test_fixed.csv')
# df.head()
df_test_label = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/투자공학_HW3데이터분석/loan_test_label.csv')
#df.info()

df_test = pd.merge(df_test,df_test_label,on='id')
df_test.drop('id',axis=1,inplace=True)
df_test = df_test.astype({'loan_status':'category'})
df_test.info()

# %%
from pycaret.classification import *

exp_name = setup(data = df,  target = 'loan_status',train_size=0.9, data_split_shuffle = True, 
                 fold_strategy='stratifiedkfold', fold=10, 
                 numeric_features=['int_rate','recoveries','annual_inc','dti','int_rate','tot_cur_bal','emp_length','inq_last_6mths','revol_util','delinq_2yrs','loan_amnt'],
                 silent = True, verbose = False, session_id = 123)

bagged_gbc =load_model('/content/drive/MyDrive/Colab Notebooks/투자공학_HW3데이터분석/bag_gbc_model')

pred_unseen = predict_model(bagged_gbc, data = df_test)

# %%
pred_unseen

# %%
sum(pred_unseen['Label']==0)

# %%
sum(pred_unseen['Label']==1)

# %%
pred_unseen.to_csv('/content/drive/MyDrive/Colab Notebooks/투자공학_HW3데이터분석/predict_tmp_file.csv')
